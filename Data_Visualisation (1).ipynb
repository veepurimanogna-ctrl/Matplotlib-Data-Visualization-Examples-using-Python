# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

subjects = ['Python', 'Java', 'C++', 'SQL']
students = [45, 38, 30, 50]

plt.bar(subjects, students)

plt.title("Students Enrolled")
plt.xlabel("Subjects")
plt.ylabel("Number of Students")

plt.show()

# %%
plt.bar(subjects, students, color='green')
plt.show()

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']
sales = [25, 30, 40, 35, 50]

plt.plot(months, sales)

plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")

plt.show()

# %%
plt.plot(months, sales,
         marker='o',
         linestyle='--',
         color='red')
plt.show()

# %%
plt.plot(months, sales,
         marker='o',
         linestyle='--',
         color='blue')
plt.show()

# %%
import matplotlib.pyplot as plt

study_hours = [1, 2, 3, 4, 5, 6, 7]
marks = [35, 40, 50, 60, 68, 80, 90]

plt.scatter(study_hours, marks)

plt.title("Study Hours vs Marks")
plt.xlabel("Study Hours")
plt.ylabel("Marks")

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.scatter(x, y, marker='s', s=100)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.scatter(x, y, marker='*', s=100)

plt.show()

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4, 5]
y = [10, 20, 30, 40, 50]

plt.scatter(x, y, marker='^', s=100)

plt.show()

# %%
import matplotlib.pyplot as plt

labels = ['Python', 'Java', 'C++', 'SQL']
students = [40, 30, 20, 10]

plt.pie(students,
        labels=labels,
        autopct='%1.1f%%',
        startangle=90)

plt.title("Students Learning Programming Languages")

plt.show()

# %%
import matplotlib.pyplot as plt

departments = ['HR', 'IT', 'Sales', 'Finance']
employees = [20, 35, 25, 30]

plt.bar(departments, employees)

plt.show()

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun']
temperature = [22, 24, 28, 32, 35, 30]

plt.plot(months, temperature)

plt.show()

# %%
import matplotlib.pyplot as plt

age = [22, 25, 30, 35, 40]
salary = [25000, 35000, 50000, 65000, 80000]

plt.scatter(age, salary)

plt.show()

# %%
import matplotlib.pyplot as plt

products = ['P1', 'P2', 'P3', 'P4', 'P5']
sales = [150, 200, 180, 250, 300]

plt.bar(products, sales)

plt.show()

# %%
import matplotlib.pyplot as plt

tests = ['Test1', 'Test2', 'Test3', 'Test4', 'Test5']
marks = [70, 75, 80, 85, 90]

plt.plot(tests, marks)

plt.show()

# %%
import matplotlib.pyplot as plt

hours = [1, 2, 3, 4, 5]
marks = [40, 50, 65, 75, 90]

plt.scatter(hours, marks)

plt.show()

# %%
import matplotlib.pyplot as plt

age = [22, 25, 28, 31, 35, 40, 45]
salary = [45000, 30000, 55000, 40000, 70000, 50000, 65000]

plt.scatter(age, salary, marker='D')

plt.show()

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']

company_a = [120, 140, 150, 170, 190]
company_b = [100, 130, 145, 160, 180]

plt.plot(months, company_a, marker='o', label='Company A')
plt.plot(months, company_b, marker='s', label='Company B')

plt.title("Monthly Sales Comparison")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

marks = [45, 50, 55, 60, 62, 65, 68, 70, 72, 75,
         78, 80, 82, 85, 88, 90, 92, 95, 98, 100]

plt.hist(marks, bins=np.arange(45, 105, 10),
         color='skyblue', edgecolor='black')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

subjects = ['Math', 'Science', 'English', 'Computer']
student1 = [85, 75, 90, 89]
student2 = [70, 85, 88, 80]

x = np.arange(len(subjects))
width = 0.35

plt.bar(x - width/2, student1, width, label='Student1')
plt.bar(x + width/2, student2, width, label='Student2')

plt.xticks(x, subjects)

plt.title("Marks Comparison")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.legend()

plt.show()

# %%
subjects =['math','science','english','computer']
student1 = [85,75,90,89]
student2 = [70,85,88,80]
#x = np.arange(len(subjects))   # x =4
width =0.35
#print(x -0.175 )
#print(width/2)
plt.bar(subjects,student1,width,label ='Student1')
plt.bar(subjects,student1,width,label ='Student2')
#plt.xticks(x, subjects)
plt.title("Marks Comparison")
plt.xlabel("Subjects")
plt.ylabel("Marks")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

months = ['Jan', 'Feb', 'Mar', 'Apr', 'May']

company_a = [120, 140, 150, 170, 190]
company_b = [100, 130, 145, 160, 180]

plt.plot(months, company_a, marker='o', label='Company A')
plt.plot(months, company_b, marker='s', label='Company B')

plt.title("Monthly Sales Comparison")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

months = ["Jan", "Feb", "Mar", "Apr", "May"]

product_A = [120, 150, 170, 160, 180]
product_B = [100, 130, 150, 145, 170]
product_C = [90, 110, 130, 120, 140]

x = np.arange(len(months))
width = 0.25

plt.bar(x - width, product_A, width, label='Product A')
plt.bar(x, product_B, width, label='Product B')
plt.bar(x + width, product_C, width, label='Product C')

plt.xticks(x, months)

plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt
years = [2020, 2021, 2022, 2023, 2024]
company_a = [20, 25, 30, 35, 40]
company_b = [18, 22, 28, 33, 38]

plt.plot(years, company_a, marker='o', label='Company A')
plt.plot(years, company_b, marker='o', label='Company B')
plt.title("Yearly Profit Comparison")
plt.xlabel("Year")
plt.ylabel("Profit")
plt.legend()

plt.show()

# %%
import matplotlib.pyplot as plt

IT = [45000, 50000, 52000, 55000, 58000, 60000, 62000]
HR = [35000, 38000, 40000, 42000, 45000, 47000, 50000]
Sales = [30000, 35000, 45000, 50000, 55000, 60000, 70000]

plt.figure(figsize=(8,5))

plt.boxplot(IT)

plt.title("Salary Distribution")
plt.xlabel("Department")
plt.ylabel("Salary (₹)")

plt.show()

# %%
import matplotlib.pyplot as plt

class_A = [45, 50, 55, 60, 62, 65, 68, 70, 72, 75, 80, 95]
class_B = [40, 48, 52, 58, 60, 64, 66, 69, 73, 76, 78, 82]

data = [class_A, class_B]

plt.boxplot(data, labels=['Class A', 'Class B'])

plt.show()
# Out:
# /tmp/ipykernel_1239/4112754453.py:8: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=['Class A', 'Class B'])
